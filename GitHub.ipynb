# %%
from getpass import getpass
import os

token = getpass("Enter your GitHub Token: ")
os.environ["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"] = token
# Out:
# Enter your GitHub Token: ··········

# %%
# !git clone https://github.com/sonuprasad23/MachineLearning.git
# Out:
# Cloning into 'MachineLearning'...
# ...

# %%
# %cd MachineLearning
# Out:
# /content/MachineLearning

# %%
import shutil

# Change "Your_Notebook.ipynb" to your actual notebook name
shutil.move("/content/GitHub.ipynb", "/content/MachineLearning/GitHub.ipynb")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/lib/python3.11/shutil.py in move(src, dst, copy_function)
#     852     try:
# --> 853         os.rename(src, real_dst)
#     854     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/GitHub.ipynb' -> '/content/MachineLearning/GitHub.ipynb'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-92a9d13a198a> in <cell line: 0>()
#       2
#       3 # Change "Your_Notebook.ipynb" to your actual notebook name
# ----> 4 shutil.move("/content/GitHub.ipynb", "/content/MachineLearning/GitHub.ipynb")
#
# /usr/lib/python3.11/shutil.py in move(src, dst, copy_function)
#     871             rmtree(src)
#     872         else:
# --> 873             copy_function(src, real_dst)
# ...

# %%
# !git config --global user.email "sonuprasadmahato31@gmail.com"
# !git config --global user.name "sonuprasad23"
# Out:
# error: src refspec refs/heads/main does not match any
# error: failed to push some refs to 'https://github.com/sonuprasad23/MachineLearning.git'
